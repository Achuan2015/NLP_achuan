# %% [markdown]
# ## BERT 在Fine-tuning时 freeze 参数的影响

# %% [markdown]
# ### freeze 全部parameter
# 载入预训练模型后，遍历 parameter 将 requires_grad 设置为 False

# %%
from transformers import BertForSequenceClassification

model_path = "/data/projects/NLP_achuan/semantic_similairy/text-semantic-similarity-bert/input/bert-base-chinese"
model = BertForSequenceClassification.from_pretrained(model_path)
# Out:
# Some weights of the model checkpoint at /data/projects/NLP_achuan/semantic_similairy/text-semantic-similarity-bert/input/bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /data/projects/NLP_achuan/semantic_similairy/text-semantic-similarity-bert/input/bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# 现在验证一下model 前参数的 requires_grad 的状态

# %%
# model 的 parameter 接口有多个
## name_paramters 会列出 parameter_name， parameter，同时 parameter 也可以
for item in model.named_parameters():
    print('name_parameter:')
    print(type(item), len(item), item[0], type(item[1]), item[1].requires_grad)
    break

## parameter 接口,
for item in model.parameters():
    print('only parameter:')
    print(type(item), len(item), item.requires_grad)
    break

## 可以单独调出 bert 的参数
for param in model.bert.base_model.named_parameters():
    print(param[0])
    break
# Out:
# name_parameter:
# <class 'tuple'> 2 bert.embeddings.word_embeddings.weight <class 'torch.nn.parameter.Parameter'> True
# only parameter:
# <class 'torch.nn.parameter.Parameter'> 21128 True
# embeddings.word_embeddings.weight

# %% [markdown]
# 现在改变 model 中 bert—base的 requires_grad 为False，然后通过named_parameters 来打印展示

# %%
# set false
for param in model.bert.base_model.parameters():
    param.requires_grad = False

for param in model.named_parameters():
    print(f'name: {param[0]}, status: {param[1].requires_grad}')
# Out:
# name: bert.embeddings.word_embeddings.weight, status: False
# name: bert.embeddings.position_embeddings.weight, status: False
# name: bert.embeddings.token_type_embeddings.weight, status: False
# name: bert.embeddings.LayerNorm.weight, status: False
# name: bert.embeddings.LayerNorm.bias, status: False
# name: bert.encoder.layer.0.attention.self.query.weight, status: False
# name: bert.encoder.layer.0.attention.self.query.bias, status: False
# name: bert.encoder.layer.0.attention.self.key.weight, status: False
# name: bert.encoder.layer.0.attention.self.key.bias, status: False
# name: bert.encoder.layer.0.attention.self.value.weight, status: False
# name: bert.encoder.layer.0.attention.self.value.bias, status: False
# name: bert.encoder.layer.0.attention.output.dense.weight, status: False
# name: bert.encoder.layer.0.attention.output.dense.bias, status: False
# name: bert.encoder.layer.0.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.0.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.0.intermediate.dense.weight, status: False
# name: bert.encoder.layer.0.intermediate.dense.bias, status: False
# name: bert.encoder.layer.0.output.dense.weight, status: False
# name: bert.encoder.layer.0.output.dense.bias, status: False
# name: bert.encoder.layer.0.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.0.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.1.attention.self.query.weight, status: False
# name: bert.encoder.layer.1.attention.self.query.bias, status: False
# name: bert.encoder.layer.1.attention.self.key.weight, status: False
# name: bert.encoder.layer.1.attention.self.key.bias, status: False
# name: bert.encoder.layer.1.attention.self.value.weight, status: False
# name: bert.encoder.layer.1.attention.self.value.bias, status: False
# name: bert.encoder.layer.1.attention.output.dense.weight, status: False
# name: bert.encoder.layer.1.attention.output.dense.bias, status: False
# name: bert.encoder.layer.1.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.1.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.1.intermediate.dense.weight, status: False
# name: bert.encoder.layer.1.intermediate.dense.bias, status: False
# name: bert.encoder.layer.1.output.dense.weight, status: False
# name: bert.encoder.layer.1.output.dense.bias, status: False
# name: bert.encoder.layer.1.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.1.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.2.attention.self.query.weight, status: False
# name: bert.encoder.layer.2.attention.self.query.bias, status: False
# name: bert.encoder.layer.2.attention.self.key.weight, status: False
# name: bert.encoder.layer.2.attention.self.key.bias, status: False
# name: bert.encoder.layer.2.attention.self.value.weight, status: False
# name: bert.encoder.layer.2.attention.self.value.bias, status: False
# name: bert.encoder.layer.2.attention.output.dense.weight, status: False
# name: bert.encoder.layer.2.attention.output.dense.bias, status: False
# name: bert.encoder.layer.2.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.2.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.2.intermediate.dense.weight, status: False
# name: bert.encoder.layer.2.intermediate.dense.bias, status: False
# name: bert.encoder.layer.2.output.dense.weight, status: False
# name: bert.encoder.layer.2.output.dense.bias, status: False
# name: bert.encoder.layer.2.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.2.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.3.attention.self.query.weight, status: False
# name: bert.encoder.layer.3.attention.self.query.bias, status: False
# name: bert.encoder.layer.3.attention.self.key.weight, status: False
# name: bert.encoder.layer.3.attention.self.key.bias, status: False
# name: bert.encoder.layer.3.attention.self.value.weight, status: False
# name: bert.encoder.layer.3.attention.self.value.bias, status: False
# name: bert.encoder.layer.3.attention.output.dense.weight, status: False
# name: bert.encoder.layer.3.attention.output.dense.bias, status: False
# name: bert.encoder.layer.3.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.3.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.3.intermediate.dense.weight, status: False
# name: bert.encoder.layer.3.intermediate.dense.bias, status: False
# name: bert.encoder.layer.3.output.dense.weight, status: False
# name: bert.encoder.layer.3.output.dense.bias, status: False
# name: bert.encoder.layer.3.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.3.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.4.attention.self.query.weight, status: False
# name: bert.encoder.layer.4.attention.self.query.bias, status: False
# name: bert.encoder.layer.4.attention.self.key.weight, status: False
# name: bert.encoder.layer.4.attention.self.key.bias, status: False
# name: bert.encoder.layer.4.attention.self.value.weight, status: False
# name: bert.encoder.layer.4.attention.self.value.bias, status: False
# name: bert.encoder.layer.4.attention.output.dense.weight, status: False
# name: bert.encoder.layer.4.attention.output.dense.bias, status: False
# name: bert.encoder.layer.4.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.4.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.4.intermediate.dense.weight, status: False
# name: bert.encoder.layer.4.intermediate.dense.bias, status: False
# name: bert.encoder.layer.4.output.dense.weight, status: False
# name: bert.encoder.layer.4.output.dense.bias, status: False
# name: bert.encoder.layer.4.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.4.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.5.attention.self.query.weight, status: False
# name: bert.encoder.layer.5.attention.self.query.bias, status: False
# name: bert.encoder.layer.5.attention.self.key.weight, status: False
# name: bert.encoder.layer.5.attention.self.key.bias, status: False
# name: bert.encoder.layer.5.attention.self.value.weight, status: False
# name: bert.encoder.layer.5.attention.self.value.bias, status: False
# name: bert.encoder.layer.5.attention.output.dense.weight, status: False
# name: bert.encoder.layer.5.attention.output.dense.bias, status: False
# name: bert.encoder.layer.5.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.5.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.5.intermediate.dense.weight, status: False
# name: bert.encoder.layer.5.intermediate.dense.bias, status: False
# name: bert.encoder.layer.5.output.dense.weight, status: False
# name: bert.encoder.layer.5.output.dense.bias, status: False
# name: bert.encoder.layer.5.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.5.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.6.attention.self.query.weight, status: False
# name: bert.encoder.layer.6.attention.self.query.bias, status: False
# name: bert.encoder.layer.6.attention.self.key.weight, status: False
# name: bert.encoder.layer.6.attention.self.key.bias, status: False
# name: bert.encoder.layer.6.attention.self.value.weight, status: False
# name: bert.encoder.layer.6.attention.self.value.bias, status: False
# name: bert.encoder.layer.6.attention.output.dense.weight, status: False
# name: bert.encoder.layer.6.attention.output.dense.bias, status: False
# name: bert.encoder.layer.6.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.6.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.6.intermediate.dense.weight, status: False
# name: bert.encoder.layer.6.intermediate.dense.bias, status: False
# name: bert.encoder.layer.6.output.dense.weight, status: False
# name: bert.encoder.layer.6.output.dense.bias, status: False
# name: bert.encoder.layer.6.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.6.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.7.attention.self.query.weight, status: False
# name: bert.encoder.layer.7.attention.self.query.bias, status: False
# name: bert.encoder.layer.7.attention.self.key.weight, status: False
# name: bert.encoder.layer.7.attention.self.key.bias, status: False
# name: bert.encoder.layer.7.attention.self.value.weight, status: False
# name: bert.encoder.layer.7.attention.self.value.bias, status: False
# name: bert.encoder.layer.7.attention.output.dense.weight, status: False
# name: bert.encoder.layer.7.attention.output.dense.bias, status: False
# name: bert.encoder.layer.7.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.7.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.7.intermediate.dense.weight, status: False
# name: bert.encoder.layer.7.intermediate.dense.bias, status: False
# name: bert.encoder.layer.7.output.dense.weight, status: False
# name: bert.encoder.layer.7.output.dense.bias, status: False
# name: bert.encoder.layer.7.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.7.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.8.attention.self.query.weight, status: False
# name: bert.encoder.layer.8.attention.self.query.bias, status: False
# name: bert.encoder.layer.8.attention.self.key.weight, status: False
# name: bert.encoder.layer.8.attention.self.key.bias, status: False
# name: bert.encoder.layer.8.attention.self.value.weight, status: False
# name: bert.encoder.layer.8.attention.self.value.bias, status: False
# name: bert.encoder.layer.8.attention.output.dense.weight, status: False
# name: bert.encoder.layer.8.attention.output.dense.bias, status: False
# name: bert.encoder.layer.8.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.8.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.8.intermediate.dense.weight, status: False
# name: bert.encoder.layer.8.intermediate.dense.bias, status: False
# name: bert.encoder.layer.8.output.dense.weight, status: False
# name: bert.encoder.layer.8.output.dense.bias, status: False
# name: bert.encoder.layer.8.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.8.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.9.attention.self.query.weight, status: False
# name: bert.encoder.layer.9.attention.self.query.bias, status: False
# name: bert.encoder.layer.9.attention.self.key.weight, status: False
# name: bert.encoder.layer.9.attention.self.key.bias, status: False
# name: bert.encoder.layer.9.attention.self.value.weight, status: False
# name: bert.encoder.layer.9.attention.self.value.bias, status: False
# name: bert.encoder.layer.9.attention.output.dense.weight, status: False
# name: bert.encoder.layer.9.attention.output.dense.bias, status: False
# name: bert.encoder.layer.9.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.9.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.9.intermediate.dense.weight, status: False
# name: bert.encoder.layer.9.intermediate.dense.bias, status: False
# name: bert.encoder.layer.9.output.dense.weight, status: False
# name: bert.encoder.layer.9.output.dense.bias, status: False
# name: bert.encoder.layer.9.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.9.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.10.attention.self.query.weight, status: False
# name: bert.encoder.layer.10.attention.self.query.bias, status: False
# name: bert.encoder.layer.10.attention.self.key.weight, status: False
# name: bert.encoder.layer.10.attention.self.key.bias, status: False
# name: bert.encoder.layer.10.attention.self.value.weight, status: False
# name: bert.encoder.layer.10.attention.self.value.bias, status: False
# name: bert.encoder.layer.10.attention.output.dense.weight, status: False
# name: bert.encoder.layer.10.attention.output.dense.bias, status: False
# name: bert.encoder.layer.10.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.10.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.10.intermediate.dense.weight, status: False
# name: bert.encoder.layer.10.intermediate.dense.bias, status: False
# name: bert.encoder.layer.10.output.dense.weight, status: False
# name: bert.encoder.layer.10.output.dense.bias, status: False
# name: bert.encoder.layer.10.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.10.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.11.attention.self.query.weight, status: False
# name: bert.encoder.layer.11.attention.self.query.bias, status: False
# name: bert.encoder.layer.11.attention.self.key.weight, status: False
# name: bert.encoder.layer.11.attention.self.key.bias, status: False
# name: bert.encoder.layer.11.attention.self.value.weight, status: False
# name: bert.encoder.layer.11.attention.self.value.bias, status: False
# name: bert.encoder.layer.11.attention.output.dense.weight, status: False
# name: bert.encoder.layer.11.attention.output.dense.bias, status: False
# name: bert.encoder.layer.11.attention.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.11.attention.output.LayerNorm.bias, status: False
# name: bert.encoder.layer.11.intermediate.dense.weight, status: False
# name: bert.encoder.layer.11.intermediate.dense.bias, status: False
# name: bert.encoder.layer.11.output.dense.weight, status: False
# name: bert.encoder.layer.11.output.dense.bias, status: False
# name: bert.encoder.layer.11.output.LayerNorm.weight, status: False
# name: bert.encoder.layer.11.output.LayerNorm.bias, status: False
# name: bert.pooler.dense.weight, status: False
# name: bert.pooler.dense.bias, status: False
# name: classifier.weight, status: True
# name: classifier.bias, status: True

# %% [markdown]
# 观察上面的结果可以发现除了 classifier 层之外的参数都被设置为了False
